# %%
# !kaggle datasets download -d gabrielramos87/an-online-shop-business
# !unzip an-online-shop-business.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/gabrielramos87/an-online-shop-business
# License(s): CC0-1.0
# an-online-shop-business.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  an-online-shop-business.zip
# replace Sales Transaction v.4a.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# # 1. Giới thiệu về tập dữ liệu

# %% [markdown]
# ## 1.1 Thông tin tập dữ liệu

# %% [markdown]
# > **Tên tập dữ liệu** : E-commerce Business Transaction: Giao dịch bán hàng của một thương mại điện tử (bán lẻ trực tuyến) có trụ sở tại Vương quốc Anh trong một năm

# %% [markdown]
# ### Bối cảnh

# %% [markdown]
# > Thương mại điện tử đã trở thành một kênh mới hỗ trợ doanh nghiệp phát triển. Thông qua thương mại điện tử, doanh nghiệp có thể tiếp cận và thiết lập sự hiện diện trên thị trường rộng hơn bằng cách cung cấp các kênh phân phối rẻ hơn và hiệu quả hơn cho sản phẩm hoặc dịch vụ của họ. Thương mại điện tử cũng đã thay đổi cách mọi người mua sắm và tiêu thụ sản phẩm và dịch vụ. Nhiều người đang chuyển sang sử dụng máy tính hoặc thiết bị thông minh để đặt hàng, những mặt hàng có thể dễ dàng được giao đến tận nhà.

# %% [markdown]
# ### Nội dung

# %% [markdown]
# > Đây là bộ dữ liệu giao dịch bán hàng của thương mại điện tử (bán lẻ trực tuyến) có trụ sở tại Vương quốc Anh trong một năm. Cửa hàng có trụ sở tại London này đã bán quà tặng và đồ gia dụng cho người lớn và trẻ em thông qua trang web từ năm 2007. Khách hàng của họ đến từ khắp nơi trên thế giới và thường mua hàng trực tiếp cho chính họ. Ngoài ra còn có các doanh nghiệp nhỏ mua số lượng lớn và bán cho khách hàng khác thông qua kênh cửa hàng bán lẻ.
#
# Tập dữ liệu chứa 500K hàng và 8 cột. Sau đây là mô tả của từng cột.
#
# - 1. TransactionNo - Số giao dịch (categorical): một số duy nhất gồm sáu chữ số xác định mỗi giao dịch. Chữ “C” trong mã biểu thị việc hủy bỏ.
# - 2. Date - Ngày (numeric): ngày mà mỗi giao dịch được tạo.
# - 3. ProductNo (categorical): ký tự duy nhất gồm năm hoặc sáu chữ số được sử dụng để xác định một sản phẩm cụ thể.
# - 4. Product - Sản phẩm (categorical): tên sản phẩm/mặt hàng.
# - 5. Price - Giá (numeric): giá của mỗi sản phẩm trên một đơn vị tính bằng bảng Anh (£).
# - 6. Quantity - Số lượng (numeric): số lượng mỗi sản phẩm trên một giao dịch. Giá trị âm liên quan đến giao dịch bị hủy.
# - 7. CustomerNo - Số khách hàng (categorical): một số duy nhất có năm chữ số xác định từng khách hàng.
# - 8. Country - quốc gia (categorical): tên quốc gia nơi khách hàng cư trú.
#
# Có một tỷ lệ nhỏ việc hủy đơn hàng trong tập dữ liệu. Hầu hết các lần hủy này là do tình trạng hết hàng của một số sản phẩm. Trong tình huống này, khách hàng có xu hướng hủy đơn hàng vì họ muốn tất cả các sản phẩm được giao cùng một lúc.

# %% [markdown]
# ## 1.2 Chi tiết tập dữ liệu

# %% [markdown]
# **Thư viện**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# load dữ liệu

# %%
df = pd.read_csv('Sales Transaction v.4a.csv')
df.head(10)
# Out:
#   TransactionNo       Date ProductNo                          ProductName  \
# 0        581482  12/9/2019     22485        Set Of 2 Wooden Market Crates
# 1        581475  12/9/2019     22596  Christmas Star Wish List Chalkboard
# 2        581475  12/9/2019     23235             Storage Tin Vintage Leaf
# 3        581475  12/9/2019     23272    Tree T-Light Holder Willie Winkie
# 4        581475  12/9/2019     23239    Set Of 4 Knick Knack Tins Poppies
# 5        581475  12/9/2019     21705              Bag 500g Swirly Marbles
# 6        581475  12/9/2019     22118             Joy Wooden Block Letters
# 7        581475  12/9/2019     22119           Peace Wooden Block Letters
# 8        581475  12/9/2019     22217          T-Light Holder Hanging Lace
# 9        581475  12/9/2019     22216            T-Light Holder White Lace
#
#    Price  Quantity  CustomerNo         Country
# 0  21.47        12     17490.0  United Kingdom
# 1  10.65        36     13069.0  United Kingdom
# 2  11.53        12     13069.0  United Kingdom
# 3  10.65        12     13069.0  United Kingdom
# 4  11.94         6     13069.0  United Kingdom
# 5  10.65        24     13069.0  United Kingdom
# 6  11.53        18     13069.0  United Kingdom
# 7  12.25        12     13069.0  United Kingdom
# 8  10.65        12     13069.0  United Kingdom
# 9  10.55        24     13069.0  United Kingdom

# %%
df.shape
# Out:
# (536350, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536350 entries, 0 to 536349
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   TransactionNo  536350 non-null  object
#  1   Date           536350 non-null  object
#  2   ProductNo      536350 non-null  object
#  3   ProductName    536350 non-null  object
#  4   Price          536350 non-null  float64
#  5   Quantity       536350 non-null  int64
#  6   CustomerNo     536295 non-null  float64
#  7   Country        536350 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 32.7+ MB

# %%
Numeric = df.select_dtypes(include=["int", "float"]).columns.tolist()
Categorical = df.select_dtypes(exclude=["int", "float"]).columns.tolist()

print("Các biến kiểu số bao gồm: {}".format(Numeric))
print("Các biến phân loại bao gồm: {}".format(Categorical))
# Out:
# Các biến kiểu số bao gồm: ['Price', 'Quantity', 'CustomerNo']
# Các biến phân loại bao gồm: ['TransactionNo', 'Date', 'ProductNo', 'ProductName', 'Country']

# %%
duplicated_quantity = df.duplicated().sum()
null_quantity = df.isnull().sum()
null_percentages = df.isnull().mean() * 100

duplicated_null_stats = pd.DataFrame({
    'Số giá trị duplicate': duplicated_quantity,
    'Số lượng giá trị null': null_quantity,
    'Tỷ lệ giá trị null (%)': null_percentages
})

print("Thông tin về duplicated value và missing value:")
print ("-"*80)
display(duplicated_null_stats)
# Out:
# Thông tin về duplicated value và missing value:
# --------------------------------------------------------------------------------
#                Số giá trị duplicate  Số lượng giá trị null  \
# TransactionNo                  5200                      0
# Date                           5200                      0
# ProductNo                      5200                      0
# ProductName                    5200                      0
# Price                          5200                      0
# Quantity                       5200                      0
# CustomerNo                     5200                     55
# Country                        5200                      0
#
#                Tỷ lệ giá trị null (%)
# TransactionNo                0.000000
# Date                         0.000000
# ProductNo                    0.000000
# ProductName                  0.000000
# Price                        0.000000
# Quantity                     0.000000
# CustomerNo                   0.010254
# Country                      0.000000

# %%
print("Unique Values")
print("-"*30)
print(df.nunique())
# Out:
# Unique Values
# ------------------------------
# TransactionNo    23204
# Date               305
# ProductNo         3768
# ProductName       3768
# Price              530
# Quantity           510
# CustomerNo        4738
# Country             38
# dtype: int64

# %% [markdown]
# Nhận xét:
# - Bộ dữ liệu chứa (536350 hàng giao dịch, 8 thuộc tính)
# - Cột 'Date' được lưu trữ dưới dạng chuỗi văn bản, không phải là định dạng ngày và giờ thích hợp
# - Cột 'CustomerNo' được lưu trữ dưới dạng số thập phân, có thể gây ra sự mơ hồ.
# - Tổng số quốc gia trong cơ sở dữ liệu là 38, tức là cửa hàng trực tuyến này có giao dịch trên khắp thế giới.
# - Một số dữ liệu bị thiếu giá trị, cột 'CustomerNo' nhưng mỗi giao dịch thường phải có 'CustomerNo'.
# - Khá nhiều dòng dữ liệu bị duplicated
# - Trong cột 'Quantity', có những giá trị âm ảnh hưởng
# - Trong cột 'Transaction', dữ liệu có chữ "C" ở đầu giá trị, điều đó chỉ ra rằng đó là giao dịch hủy bỏ.

# %% [markdown]
# # 2. Tiền xử lý dữ liệu

# %% [markdown]
# ## 2.1 Xử lý dữ liệu bị thiếu (NULL)

# %%
df = df.dropna()

print ("Missing Values")
print ("-"*30)
print(df.isnull().sum())
# Out:
# Missing Values
# ------------------------------
# TransactionNo    0
# Date             0
# ProductNo        0
# ProductName      0
# Price            0
# Quantity         0
# CustomerNo       0
# Country          0
# dtype: int64

# %% [markdown]
# ## 2.2. Xử lý giá trị trùng lặp (Duplicate)

# %%
df = df.drop_duplicates(keep=False)

# %% [markdown]
# ## 2.3. Xử lý nhiễu

# %%
# Cột Date
#Thay đổi loại 'Date' thành DateTime
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# <ipython-input-58-201e1a52b366>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
# Quantity và  Transaction
#Xóa giao dịch hủy dựa trên số lượng dưới 0
df = df[df['Quantity'] > 0]

# %%
# CustomerNo
# Thay đổi kiểu dữ liệu 'Customerno' và 'TransfictionId' thành số nguyên
df['CustomerNo'] = df['CustomerNo'].astype(int)
df['TransactionNo'] = df['TransactionNo'].astype(int)
# Out:
# <ipython-input-60-c0f740d75535>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CustomerNo'] = df['CustomerNo'].astype(int)
# <ipython-input-60-c0f740d75535>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['TransactionNo'] = df['TransactionNo'].astype(int)

# %% [markdown]
# ## 2.4. Xử lý dữ liệu Outlier

# %% [markdown]
# ## 2.5 Thêm thuộc tính

# %% [markdown]
# Create a new calculated column 'Revenue' by multiplying 'Price' and 'Quantity'
#
# Create a new calculated column 'Day' extracting the day from the 'Date' column
#
# Create a new calculated column 'Month' extracting the month from the 'Date' column
#
# Create a new calculated column 'Year' extracting the year from the 'Date' column
#
# -> thuật tiện trong việc EDA

# %% [markdown]
# #### 2.6 PCA

# %% [markdown]
# # 3.Phân tích dữ liệu thăm dò (EDA) và Trực quan hóa

# %% [markdown]
# - Xu hướng bán hàng qua các tháng như thế nào?
# - Sản phẩm được mua thường xuyên nhất là gì?
# - Khách hàng mua bao nhiêu sản phẩm trong mỗi giao dịch?
# - Phân khúc khách hàng có lợi nhất là gì?
# - Dựa trên những phát hiện của bạn, bạn có thể đề xuất chiến lược nào cho doanh nghiệp để thu được nhiều lợi nhuận hơn?
#
# ....... có thể thêm nhiều câu khác

# %%
# Setting the date and time
start_date = df.Date.min()
end_date = df.Date.max()
period = end_date - start_date

print("Start:", start_date)
print("End:", end_date)
print("Period:", period)
# Out:
# Start: 2018-12-01 00:00:00
# End: 2019-12-09 00:00:00
# Period: 373 days 00:00:00

# %% [markdown]
# # 4. Mô hình

# %% [markdown]
# ## 4.1 Clustering with k-means

# %% [markdown]
# ## 4.2 Khai phá kết hợp Apriori, FP-Growth,....
# -> này chưa thử, nhưng có vẻ được

# %% [markdown]
# ## 4.3 Mô Hình Dự Báo

# %% [markdown]
# VD:
# -Linear Regression
# -DecisionTreeRegressor
# -Random Forest

# %% [markdown]
# ## 4.4 Timeseri
# -> này mình tạo thêm cột Revenue:  doanh thu = Price * Quantity, xong xây mô hình

# %%
# Tính doanh thu
df['Revenue'] = df['Price'] * df['Quantity']
# Out:
# <ipython-input-62-11fa880b45c7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'] = df['Price'] * df['Quantity']

# %% [markdown]
# Xây dựng model

# %%
# Gộp doanh thu của các ngày lại
df_grouped = df.groupby('Date')['Revenue'].sum().reset_index()

# Đổi tên cột Date thành Date và cột Revenue thành TotalRevenue
df_grouped.columns = ['Date', 'TotalRevenue']

# In ra một số dòng đầu của tập dữ liệu mới
df_grouped
# Out:
#           Date  TotalRevenue
# 0   2018-12-01     324344.92
# 1   2018-12-02     365799.61
# 2   2018-12-03     205429.00
# 3   2018-12-05     192737.54
# 4   2018-12-06     269519.28
# ..         ...           ...
# 300 2019-12-05     288494.27
# 301 2019-12-06     196635.48
# 302 2019-12-07     263447.82
# 303 2019-12-08     222438.02
# 304 2019-12-09    1106005.97
#
# [305 rows x 2 columns]

# %%
# Tạo ra các đặc trưng mới từ cột Date
df_grouped['Date'] = pd.to_datetime(df_grouped['Date'])
df_grouped['Year'] = df_grouped['Date'].dt.year
df_grouped['Month'] = df_grouped['Date'].dt.month
df_grouped['Day'] = df_grouped['Date'].dt.day
df_grouped['DayOfWeek'] = df_grouped['Date'].dt.dayofweek

# %%
df_grouped
# Out:
#           Date  TotalRevenue  Year  Month  Day  DayOfWeek
# 0   2018-12-01     324344.92  2018     12    1          5
# 1   2018-12-02     365799.61  2018     12    2          6
# 2   2018-12-03     205429.00  2018     12    3          0
# 3   2018-12-05     192737.54  2018     12    5          2
# 4   2018-12-06     269519.28  2018     12    6          3
# ..         ...           ...   ...    ...  ...        ...
# 300 2019-12-05     288494.27  2019     12    5          3
# 301 2019-12-06     196635.48  2019     12    6          4
# 302 2019-12-07     263447.82  2019     12    7          5
# 303 2019-12-08     222438.02  2019     12    8          6
# 304 2019-12-09    1106005.97  2019     12    9          0
#
# [305 rows x 6 columns]

# %% [markdown]
# **Loại bỏ giá trị ngoại lai**

# %%
import pandas as pd

# Tính toán giá trị trung bình và độ lệch chuẩn của cột TotalRevenue
mean = df_grouped['TotalRevenue'].mean()
std_dev = df_grouped['TotalRevenue'].std()

# Xác định ngưỡng
threshold = 3 * std_dev

# Loại bỏ các hàng có giá trị TotalRevenue nằm ngoài khoảng giới hạn
df_grouped = df_grouped[(df_grouped['TotalRevenue'] >= mean - threshold) & (df_grouped['TotalRevenue'] <= mean + threshold)]

# In ra dữ liệu đã được làm sạch
print(df_grouped)
# Out:
#           Date  TotalRevenue  Year  Month       Day  DayOfWeek
# 0   2018-12-01      0.278524   0.0    1.0  0.000000   0.833333
# 1   2018-12-02      0.316786   0.0    1.0  0.033333   1.000000
# 2   2018-12-03      0.168764   0.0    1.0  0.066667   0.000000
# 3   2018-12-05      0.157049   0.0    1.0  0.133333   0.333333
# 4   2018-12-06      0.227919   0.0    1.0  0.166667   0.500000
# ..         ...           ...   ...    ...       ...        ...
# 299 2019-12-04      0.051088   1.0    1.0  0.100000   0.333333
# 300 2019-12-05      0.245433   1.0    1.0  0.133333   0.500000
# 301 2019-12-06      0.160647   1.0    1.0  0.166667   0.666667
# 302 2019-12-07      0.222315   1.0    1.0  0.200000   0.833333
# 303 2019-12-08      0.184463   1.0    1.0  0.233333   1.000000
#
# [302 rows x 6 columns]

# %% [markdown]
# #### Dùng GridSearchCV

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.base import BaseEstimator, RegressorMixin
import matplotlib.pyplot as plt


# Chuẩn hóa dữ liệu về khoảng [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']] = scaler.fit_transform(df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']])

# Chia dữ liệu thành các chuỗi thời gian
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data.iloc[i:i + seq_length, 2:])
        y.append(data.iloc[i + seq_length, 1])
    return np.array(X), np.array(y)

seq_length = 10  # Độ dài chuỗi thời gian
X, y = create_sequences(df_grouped, seq_length)

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Lớp tuỳ chỉnh để sử dụng mô hình Keras với GridSearchCV
class KerasLSTMRegressor(BaseEstimator, RegressorMixin):
    def __init__(self, units=100, activation='sigmoid', optimizer='adam', dropout=0.0, recurrent_dropout=0.0, epochs=10, batch_size=32, input_shape=(seq_length, 4)):
        self.units = units
        self.activation = activation
        self.optimizer = optimizer
        self.dropout = dropout
        self.recurrent_dropout = recurrent_dropout
        self.epochs = epochs
        self.batch_size = batch_size
        self.input_shape = input_shape
        self.model = None

    def build_model(self):
        model = Sequential([
            LSTM(units=self.units, activation=self.activation, input_shape=self.input_shape, dropout=self.dropout, recurrent_dropout=self.recurrent_dropout),
            Dense(units=1)
        ])
        model.compile(optimizer=self.optimizer, loss='mse')
        return model

    def fit(self, X, y):
        self.model = self.build_model()
        self.model.fit(X, y, epochs=self.epochs, batch_size=self.batch_size, verbose=0)
        return self

    def predict(self, X):
        return self.model.predict(X).flatten()

# Tham số lưới mở rộng
param_grid = {
    'units': [65, 75, 85],
    'activation': ['relu', 'tanh'],
    'optimizer': ['adam'],
    'epochs': [60, 80,100],
    'batch_size': [32],
    'dropout': [0.0, 0.2]
}

# Grid search
lstm_regressor = KerasLSTMRegressor(input_shape=(seq_length, X_train.shape[2]))
grid_search = GridSearchCV(estimator=lstm_regressor, param_grid=param_grid, cv=3, n_jobs=1)
grid_result = grid_search.fit(X_train, y_train)

# In ra các kết quả
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# Dự đoán và đánh giá mô hình với tham số tốt nhất
best_model = grid_result.best_estimator_
y_pred = best_model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Data: {mse}')
# Out:
# <ipython-input-95-4cdaf7a0fcc2>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']] = scaler.fit_transform(df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']])
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 4ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 9ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 10ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 1s 5ms/step
# 3/3 [==============================] - 0s 7ms/step
# 3/3 [==============================] - 1s 6ms/step
# 3/3 [==============================] - 1s 7ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 0s 5ms/step
# 3/3 [==============================] - 12s 6ms/step
# 3/3 [==============================] - 0s 5ms/step
# Best: 0.377984 using {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 85}
# 0.286578 (0.059913) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 60, 'optimizer': 'adam', 'units': 65}
# 0.299453 (0.028694) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 60, 'optimizer': 'adam', 'units': 75}
# 0.309862 (0.069706) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 60, 'optimizer': 'adam', 'units': 85}
# 0.309196 (0.009751) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 80, 'optimizer': 'adam', 'units': 65}
# 0.334337 (0.004865) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 80, 'optimizer': 'adam', 'units': 75}
# 0.279623 (0.036892) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 80, 'optimizer': 'adam', 'units': 85}
# 0.255168 (0.060381) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 65}
# 0.267881 (0.019465) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 75}
# 0.238600 (0.018226) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 85}
# 0.089045 (0.181052) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 60, 'optimizer': 'adam', 'units': 65}
# 0.260758 (0.047968) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 60, 'optimizer': 'adam', 'units': 75}
# 0.130524 (0.162472) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 60, 'optimizer': 'adam', 'units': 85}
# 0.268026 (0.070500) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 80, 'optimizer': 'adam', 'units': 65}
# 0.203913 (0.083738) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 80, 'optimizer': 'adam', 'units': 75}
# 0.229145 (0.118456) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 80, 'optimizer': 'adam', 'units': 85}
# 0.265310 (0.051696) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 100, 'optimizer': 'adam', 'units': 65}
# 0.307338 (0.066064) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 100, 'optimizer': 'adam', 'units': 75}
# 0.286073 (0.086009) with: {'activation': 'relu', 'batch_size': 32, 'dropout': 0.2, 'epochs': 100, 'optimizer': 'adam', 'units': 85}
# 0.284850 (0.095759) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 60, 'optimizer': 'adam', 'units': 65}
# 0.355233 (0.017074) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 60, 'optimizer': 'adam', 'units': 75}
# 0.349556 (0.013773) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 60, 'optimizer': 'adam', 'units': 85}
# 0.362541 (0.020757) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 80, 'optimizer': 'adam', 'units': 65}
# 0.362057 (0.019740) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 80, 'optimizer': 'adam', 'units': 75}
# 0.335181 (0.021917) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 80, 'optimizer': 'adam', 'units': 85}
# 0.303359 (0.060661) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 65}
# 0.348771 (0.014155) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 75}
# 0.377984 (0.014734) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 85}
# 0.309852 (0.051423) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 60, 'optimizer': 'adam', 'units': 65}
# 0.280339 (0.102997) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 60, 'optimizer': 'adam', 'units': 75}
# 0.310775 (0.024124) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 60, 'optimizer': 'adam', 'units': 85}
# 0.273492 (0.058289) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 80, 'optimizer': 'adam', 'units': 65}
# 0.307226 (0.060452) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 80, 'optimizer': 'adam', 'units': 75}
# 0.322669 (0.037890) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 80, 'optimizer': 'adam', 'units': 85}
# 0.325013 (0.058853) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 100, 'optimizer': 'adam', 'units': 65}
# 0.335669 (0.043826) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 100, 'optimizer': 'adam', 'units': 75}
# 0.262588 (0.132258) with: {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.2, 'epochs': 100, 'optimizer': 'adam', 'units': 85}
# 3/3 [==============================] - 1s 8ms/step
# Mean Squared Error on Test Data: 0.016689701179686947

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Assuming df_grouped is already loaded
# Example: df_grouped = pd.read_csv('data_grouped.csv')

# Chuẩn hóa dữ liệu về khoảng [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']] = scaler.fit_transform(df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']])

# Chia dữ liệu thành các chuỗi thời gian
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data.iloc[i:i + seq_length, 2:])
        y.append(data.iloc[i + seq_length, 1])
    return np.array(X), np.array(y)

seq_length = 10  # Độ dài chuỗi thời gian
X, y = create_sequences(df_grouped, seq_length)

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Xây dựng mô hình với tham số tốt nhất
best_params = {'activation': 'tanh', 'batch_size': 32, 'dropout': 0.0, 'epochs': 100, 'optimizer': 'adam', 'units': 85}

def create_lstm_model(units, activation, dropout, optimizer, input_shape=(seq_length, 4)):
    model = Sequential([
        LSTM(units=units, activation=activation, input_shape=input_shape, dropout=dropout),
        Dense(units=1)
    ])
    model.compile(optimizer=optimizer, loss='mse')
    return model

# Train the model with the best parameters on the full training data
model = create_lstm_model(
    units=best_params['units'],
    activation=best_params['activation'],
    dropout=best_params['dropout'],
    optimizer=best_params['optimizer'],
    input_shape=(seq_length, X_train.shape[2])
)

history = model.fit(X_train, y_train, epochs=best_params['epochs'], batch_size=best_params['batch_size'], validation_split=0.2, verbose=1)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error on Test Data: {mse}')


# Plot the training and validation loss over epochs
plt.figure(figsize=(14, 5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


# Rescale the predictions and actual values back to their original scale
y_test_original = scaler.inverse_transform(np.concatenate((np.zeros((y_test.shape[0], 4)), y_test.reshape(-1, 1)), axis=1))[:, 4]
y_pred_original = scaler.inverse_transform(np.concatenate((np.zeros((y_pred.shape[0], 4)), y_pred.reshape(-1, 1)), axis=1))[:, 4]

# Tạo DataFrame chứa giá trị dự đoán và giá trị thực tế
results_df_grouped = pd.DataFrame({'Actual': y_test_original, 'Predicted': y_pred_original})

# Hiển thị DataFrame
print(results_df_grouped.head())

# Hiển thị kết quả so sánh bằng biểu đồ
plt.figure(figsize=(14, 5))
plt.plot(results_df_grouped['Actual'], label='Actual TotalRevenue')
plt.plot(results_df_grouped['Predicted'], label='Predicted TotalRevenue')
plt.title('Actual vs Predicted TotalRevenue')
plt.xlabel('Samples')
plt.ylabel('TotalRevenue')
plt.legend()
plt.show()
# Out:
# <ipython-input-96-b857f70c5a25>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']] = scaler.fit_transform(df_grouped[['TotalRevenue', 'Year', 'Month', 'Day', 'DayOfWeek']])
# Epoch 1/100
# 6/6 [==============================] - 3s 118ms/step - loss: 0.1001 - val_loss: 0.0503
# Epoch 2/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0543 - val_loss: 0.0364
# Epoch 3/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0336 - val_loss: 0.0213
# Epoch 4/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0378 - val_loss: 0.0220
# Epoch 5/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0312 - val_loss: 0.0306
# Epoch 6/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0330 - val_loss: 0.0409
# Epoch 7/100
# 6/6 [==============================] - 0s 14ms/step - loss: 0.0337 - val_loss: 0.0285
# Epoch 8/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0301 - val_loss: 0.0247
# Epoch 9/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0302 - val_loss: 0.0262
# Epoch 10/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0289 - val_loss: 0.0240
# Epoch 11/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0299 - val_loss: 0.0229
# Epoch 12/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0298 - val_loss: 0.0260
# Epoch 13/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0293 - val_loss: 0.0294
# Epoch 14/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0292 - val_loss: 0.0279
# Epoch 15/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0281 - val_loss: 0.0267
# Epoch 16/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0296 - val_loss: 0.0318
# Epoch 17/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0275 - val_loss: 0.0245
# Epoch 18/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0284 - val_loss: 0.0270
# Epoch 19/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0277 - val_loss: 0.0300
# Epoch 20/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0272 - val_loss: 0.0227
# Epoch 21/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0296 - val_loss: 0.0226
# Epoch 22/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0262 - val_loss: 0.0357
# Epoch 23/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0298 - val_loss: 0.0258
# Epoch 24/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0293 - val_loss: 0.0205
# Epoch 25/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0271 - val_loss: 0.0281
# Epoch 26/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0265 - val_loss: 0.0225
# Epoch 27/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0275 - val_loss: 0.0226
# Epoch 28/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0265 - val_loss: 0.0264
# Epoch 29/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0270 - val_loss: 0.0296
# Epoch 30/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0262 - val_loss: 0.0244
# Epoch 31/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0267 - val_loss: 0.0229
# Epoch 32/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0268 - val_loss: 0.0326
# Epoch 33/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0282 - val_loss: 0.0296
# Epoch 34/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0256 - val_loss: 0.0221
# Epoch 35/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0265 - val_loss: 0.0274
# Epoch 36/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0265 - val_loss: 0.0311
# Epoch 37/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0248 - val_loss: 0.0230
# Epoch 38/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0246 - val_loss: 0.0267
# Epoch 39/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0253 - val_loss: 0.0271
# Epoch 40/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0239 - val_loss: 0.0238
# Epoch 41/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0249 - val_loss: 0.0271
# Epoch 42/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0245 - val_loss: 0.0219
# Epoch 43/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0254 - val_loss: 0.0299
# Epoch 44/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0241 - val_loss: 0.0224
# Epoch 45/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0243 - val_loss: 0.0368
# Epoch 46/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0269 - val_loss: 0.0284
# Epoch 47/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0246 - val_loss: 0.0221
# Epoch 48/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.0241 - val_loss: 0.0302
# Epoch 49/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0234 - val_loss: 0.0236
# Epoch 50/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0229 - val_loss: 0.0223
# Epoch 51/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0229 - val_loss: 0.0307
# Epoch 52/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0230 - val_loss: 0.0220
# Epoch 53/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.0227 - val_loss: 0.0245
# Epoch 54/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0222 - val_loss: 0.0244
# Epoch 55/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0217 - val_loss: 0.0254
# Epoch 56/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0219 - val_loss: 0.0283
# Epoch 57/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0216 - val_loss: 0.0277
# Epoch 58/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0216 - val_loss: 0.0254
# Epoch 59/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0226 - val_loss: 0.0236
# Epoch 60/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0216 - val_loss: 0.0270
# Epoch 61/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0218 - val_loss: 0.0170
# Epoch 62/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0245 - val_loss: 0.0221
# Epoch 63/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0208 - val_loss: 0.0248
# Epoch 64/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0204 - val_loss: 0.0269
# Epoch 65/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0212 - val_loss: 0.0275
# Epoch 66/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0218 - val_loss: 0.0273
# Epoch 67/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0197 - val_loss: 0.0202
# Epoch 68/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0199 - val_loss: 0.0257
# Epoch 69/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0204 - val_loss: 0.0254
# Epoch 70/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0196 - val_loss: 0.0259
# Epoch 71/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0234 - val_loss: 0.0288
# Epoch 72/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0220 - val_loss: 0.0204
# Epoch 73/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0202 - val_loss: 0.0257
# Epoch 74/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0202 - val_loss: 0.0240
# Epoch 75/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0194 - val_loss: 0.0198
# Epoch 76/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0207 - val_loss: 0.0240
# Epoch 77/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0196 - val_loss: 0.0290
# Epoch 78/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0199 - val_loss: 0.0206
# Epoch 79/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0201 - val_loss: 0.0258
# Epoch 80/100
# 6/6 [==============================] - 0s 15ms/step - loss: 0.0198 - val_loss: 0.0266
# Epoch 81/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0193 - val_loss: 0.0246
# Epoch 82/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0206 - val_loss: 0.0265
# Epoch 83/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0196 - val_loss: 0.0185
# Epoch 84/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0196 - val_loss: 0.0239
# Epoch 85/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0194 - val_loss: 0.0240
# Epoch 86/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0194 - val_loss: 0.0263
# Epoch 87/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0193 - val_loss: 0.0207
# Epoch 88/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0225 - val_loss: 0.0218
# Epoch 89/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0191 - val_loss: 0.0274
# Epoch 90/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0192 - val_loss: 0.0203
# Epoch 91/100
# 6/6 [==============================] - 0s 17ms/step - loss: 0.0196 - val_loss: 0.0222
# Epoch 92/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.0203 - val_loss: 0.0302
# Epoch 93/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0190 - val_loss: 0.0215
# Epoch 94/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0201 - val_loss: 0.0239
# Epoch 95/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.0185 - val_loss: 0.0299
# Epoch 96/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0195 - val_loss: 0.0241
# Epoch 97/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.0189 - val_loss: 0.0245
# Epoch 98/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0194 - val_loss: 0.0249
# Epoch 99/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0201 - val_loss: 0.0176
# Epoch 100/100
# 6/6 [==============================] - 0s 16ms/step - loss: 0.0218 - val_loss: 0.0209
# 3/3 [==============================] - 0s 6ms/step
# Mean Squared Error on Test Data: 0.01772256678159202
#      Actual  Predicted
# 0  0.360408   0.243761
# 1  0.322939   0.429161
# 2  0.466272   0.272465
# 3  0.302822   0.311026
# 4  0.401978   0.361745

# %% [markdown]
# ARIMA

# %% [markdown]
# # 5. Kết luận
